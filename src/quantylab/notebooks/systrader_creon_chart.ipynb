# %%
# %load_ext autoreload
# %autoreload 2

from quantylab.systrader.creon import Creon
c = Creon()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
c.get_chart('005930', n=60)
# Out:
# [{'date': 20210311,
#   'open': 81000.0,
#   'high': 82500.0,
#   'low': 81000.0,
#   'close': 82000.0,
#   'diff': 1100.0,
#   'volume': 23818297,
#   'price': 1952165000000,
#   'diffsign': '2',
#   'code': '005930',
#   'diffratio': 1.3597033374536465},
#  {'date': 20210312,
#   'open': 83100.0,
#   'high': 83500.0,
#   'low': 82400.0,
#   'close': 82800.0,
#   'diff': 800.0,
#   'volume': 13530573,
#   'price': 1121129000000,
#   'diffsign': '2',
#   'code': '005930',
#   'diffratio': 0.975609756097561},
#  {'date': 20210315,
#   'open': 82800.0,
#   'high': 82900.0,
#   'low': 81800.0,
#   'close': 81800.0,
#   'diff': -1000.0,
#   'volume': 13735798,
#   'price': 1128533000000,
#   'diffsign': '5',
#   'code': '005930',
#   'diffratio': -1.2077294685990339},
#  {'date': 20210316,
#   'open': 82200.0,
#   'high': 83000.0,
#   'low': 82100.0,
#   'close': 82800.0,
#   'diff': 1000.0,
#   'volume': 12293537,
#   'price': 1014281000000,
#   'diffsign': '2',
#   'code': '005930',
# ...
